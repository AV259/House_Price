# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/train-chennai-sale.csv")
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# ...

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %% [markdown]
# Filling in the Missing values in N_Bedroom , N_Bathroom , QS_Overall

# %%
df['N_BEDROOM'].fillna(df['N_BEDROOM'].mode()[0] , inplace=True)

# %%
df['N_BATHROOM'].fillna(df['N_BATHROOM'].mode()[0] , inplace=True)

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         0
# N_BATHROOM        0
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df.drop_duplicates().shape
# Out:
# (7109, 22)

# %%
df['QS_OVERALL'].fillna((df['QS_BATHROOM']+df['QS_BEDROOM']+df['QS_ROOMS']/3), inplace=True)

# %%
df.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %% [markdown]
# Dropping the Unnecssary Columns

# %%
df1 = df.drop(['PRT_ID','REG_FEE','COMMIS'],axis=1)
df1.head()
# Out:
#          AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0  Karapakkam      1004  04-05-2011            131        1.0         1.0
# 1  Anna Nagar      1986  19-12-2006             26        2.0         1.0
# 2       Adyar       909  04-02-2012             70        1.0         1.0
# 3   Velachery      1855  13-03-2010             14        3.0         2.0
# 4  Karapakkam      1226  05-10-2009             84        1.0         1.0
#
#    N_ROOM SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE UTILITY_AVAIL  STREET  \
# 0       3  AbNormal        Yes  15-05-1967  Commercial        AllPub   Paved
# 1       5  AbNormal         No  22-12-1995  Commercial        AllPub  Gravel
# 2       3  AbNormal        Yes  09-02-1992  Commercial           ELO  Gravel
# 3       5    Family         No  18-03-1988      Others       NoSewr    Paved
# 4       3  AbNormal        Yes  13-10-1979      Others        AllPub  Gravel
#
# ...

# %% [markdown]
# Correcting the spelling mistakes in the Category columns

# %%
df1['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
df1['AREA'].replace(['Ana Nagar','Ann Nagar'],'Anna Nagar',inplace=True)
df1['AREA'].replace(['Karapakam'],'Karapakkam',inplace=True)
df1['AREA'].replace(['Adyr'],'Adyar',inplace=True)
df1['AREA'].replace(['Velchery'],'Velachery',inplace=True)
df1['AREA'].replace(['Chrompt','Chrmpet','Chormpet'],'Chrompet',inplace=True)
df1['AREA'].replace(['KKNagar'],'KK Nagar',inplace=True)
df1['AREA'].replace(['TNagar'],'T Nagar',inplace=True)

# %%
df1['SALE_COND'].unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %%
df1['SALE_COND'].replace(['Ab Normal'],'AbNormal',inplace=True)
df1['SALE_COND'].replace(['Partiall','PartiaLl'],'Partial',inplace=True)
df1['SALE_COND'].replace(['Adj Land'],'AdjLand',inplace=True)

# %%
df1['PARK_FACIL'].unique()
# Out:
# array(['Yes', 'No', 'Noo'], dtype=object)

# %%
df1['PARK_FACIL'].replace(['Noo'],'No',inplace=True)

# %%
df1['BUILDTYPE'].unique()
# Out:
# array(['Commercial', 'Others', 'Other', 'House', 'Comercial'],
#       dtype=object)

# %%
df1['BUILDTYPE'].replace(['Comercial'],'Commercial',inplace=True)
df1['BUILDTYPE'].replace(['Others'],'Other',inplace=True)

# %%
df1['UTILITY_AVAIL'].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa', 'All Pub'], dtype=object)

# %%
df1['UTILITY_AVAIL'].replace(['AllPub'],'All Pub',inplace=True)

# %%
df1['STREET'].unique()
# Out:
# array(['Paved', 'Gravel', 'No Access', 'Pavd', 'NoAccess'], dtype=object)

# %%
df1['STREET'].replace(['Pavd'],'Paved',inplace=True)
df1['STREET'].replace(['NoAccess'],'No Access',inplace=True)

# %%
df1['MZZONE'].unique()
# Out:
# array(['A', 'RH', 'RL', 'I', 'C', 'RM'], dtype=object)

# %%
df1['UTILITY_AVAIL'].replace(['NoSeWa'],'NoSewr',inplace=True)
df1['UTILITY_AVAIL'].replace(['NoSewr '],'NoSewr',inplace=True)

# %% [markdown]
# Converting to Proper Data type

# %%
df1['DATE_BUILD'] = pd.to_datetime(df1['DATE_BUILD'],format='%d-%m-%Y')
df1['DATE_SALE'] = pd.to_datetime(df1['DATE_SALE'],format='%d-%m-%Y')
df1['N_BATHROOM'] = df1['N_BATHROOM'].astype(int)
df1['N_BEDROOM'] = df1['N_BEDROOM'].astype(int)

# %%
df1.dtypes
# Out:
# AREA                     object
# INT_SQFT                  int64
# DATE_SALE        datetime64[ns]
# DIST_MAINROAD             int64
# N_BEDROOM                 int64
# N_BATHROOM                int64
# N_ROOM                    int64
# SALE_COND                object
# PARK_FACIL               object
# DATE_BUILD       datetime64[ns]
# BUILDTYPE                object
# UTILITY_AVAIL            object
# STREET                   object
# MZZONE                   object
# QS_ROOMS                float64
# QS_BATHROOM             float64
# QS_BEDROOM              float64
# QS_OVERALL              float64
# SALES_PRICE               int64
# dtype: object

# %% [markdown]
# Exploratory Data Analyis

# %%
import seaborn as sns

# %%
fig , ax = plt.subplots(figsize = (10,5))
area = df1.groupby('AREA')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['AREA']
sns.barplot(x = 'AREA' , y = 'SALES_PRICE', data = df1 , order = area , ax= ax)

# %% [markdown]
# There is a linear relationship bw area and sales price , so will be doing lable encoding now

# %%
df1['AREA'] = df1['AREA'].map({'Karapakkam': 1 ,'Adyar': 2 , 'Chrompet' : 3 , 'Velachery' : 4 , 'KK Nagar' : 5 , 'Anna Nagar' : 6 , 'T Nagar' : 7})
df1['AREA'].value_counts()
# Out:
# 3    1702
# 1    1366
# 5     997
# 4     981
# 6     788
# 2     774
# 7     501
# Name: AREA, dtype: int64

# %%
fig , ax = plt.subplots(figsize = (10,5))
sale_cond = df1.groupby('SALE_COND')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['SALE_COND']
sns.barplot(x = 'SALE_COND' , y = 'SALES_PRICE', data = df1 , order = sale_cond , ax= ax)

# %% [markdown]
# There is no considerable relation bw sale_cond and sale price , so will be dropping the column

# %%
fig , ax = plt.subplots(figsize = (10,5))
park = df1.groupby('PARK_FACIL')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['PARK_FACIL']
sns.barplot(x = 'PARK_FACIL' , y = 'SALES_PRICE', data = df1 , order = park , ax= ax)

# %% [markdown]
# Label encoding on park_facil

# %%
df1['PARK_FACIL'] = df1['PARK_FACIL'].map({'No': 0 , 'Yes' : 1})

# %%
fig , ax = plt.subplots(figsize = (10,5))
build = df1.groupby('BUILDTYPE')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['BUILDTYPE']
sns.barplot(x = 'BUILDTYPE' , y = 'SALES_PRICE', data = df1 , order = build , ax= ax)

# %% [markdown]
# No Linear relationship bw build type and sale price , so will be doing One hot encoding

# %%
df1 = pd.get_dummies(df1 , columns=['BUILDTYPE'])
df1.head()
# Out:
#    AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0     1      1004 2011-05-04            131          1           1       3
# 1     6      1986 2006-12-19             26          2           1       5
# 2     2       909 2012-02-04             70          1           1       3
# 3     4      1855 2010-03-13             14          3           2       5
# 4     1      1226 2009-10-05             84          1           1       3
#
#   SALE_COND  PARK_FACIL DATE_BUILD  ...  STREET MZZONE QS_ROOMS  QS_BATHROOM  \
# 0  AbNormal           1 1967-05-15  ...   Paved      A      4.0          3.9
# 1  AbNormal           0 1995-12-22  ...  Gravel     RH      4.9          4.2
# 2  AbNormal           1 1992-02-09  ...  Gravel     RL      4.1          3.8
# 3    Family           0 1988-03-18  ...   Paved      I      4.7          3.9
# 4  AbNormal           1 1979-10-13  ...  Gravel      C      3.0          2.5
#
# ...

# %%
fig , ax = plt.subplots(figsize = (10,5))
utility = df1.groupby('UTILITY_AVAIL')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['UTILITY_AVAIL']
sns.barplot(x = 'UTILITY_AVAIL' , y = 'SALES_PRICE', data = df1 , order = utility , ax= ax)

# %% [markdown]
# Linear relationship , so label encode

# %%
df1['UTILITY_AVAIL'] = df1['UTILITY_AVAIL'].map({'ELO' : 1 ,'NoSewr' : 2 ,'All Pub' : 3})

# %%
fig , ax = plt.subplots(figsize = (10,5))
street = df1.groupby('STREET')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['STREET']
sns.barplot(x = 'STREET' , y = 'SALES_PRICE', data = df1 , order = street , ax= ax)

# %% [markdown]
# Linear relationship , so label encoding

# %%
df1['STREET'] = df1['STREET'].map({'No Access' : 1 , 'Paved' : 2 , 'Gravel' : 3})

# %%
fig , ax = plt.subplots(figsize = (10,5))
mzone = df1.groupby('MZZONE')['SALES_PRICE'].mean().reset_index().sort_values('SALES_PRICE')['MZZONE']
sns.barplot(x = 'MZZONE' , y = 'SALES_PRICE', data = df1 , order = mzone , ax= ax)

# %% [markdown]
# There is linear relationship , but slight diff btw I & RH , so will do label encoding , skipping a code in btw .

# %%
df1['MZZONE'] = df1['MZZONE'].map({'A':1 , 'C':2 , 'I':3 , 'RH':5 , 'RL':6 , 'RM':7})

# %% [markdown]
# Checking the numerical columns now

# %%
sns.barplot(x='N_BEDROOM' , y='SALES_PRICE', data = df1)

# %%
sns.barplot(x='N_BATHROOM' , y='SALES_PRICE', data = df1)

# %%
sns.barplot(x='N_ROOM' , y='SALES_PRICE', data = df1)

# %%
sns.scatterplot(x='INT_SQFT', y='SALES_PRICE', data = df1)
plt.show()

# %% [markdown]
# Linear relationship btw int_sqft and sales price

# %%
sns.scatterplot(x='DATE_SALE' , y='SALES_PRICE', data=df1)
plt.show()

# %% [markdown]
# No Relation

# %%
sns.scatterplot(data=df1 , x='DIST_MAINROAD' , y='SALES_PRICE')
plt.show()

# %% [markdown]
# No Relation

# %%
sns.scatterplot(x='DATE_BUILD' , y='SALES_PRICE', data=df1)
plt.show()

# %% [markdown]
# No Relation

# %%
sns.scatterplot(x='QS_ROOMS' , y='SALES_PRICE', data=df1)
plt.show()

# %%
sns.scatterplot(x='QS_BATHROOM' , y='SALES_PRICE', data=df1)
plt.show()

# %%
sns.scatterplot(x='QS_BEDROOM' , y='SALES_PRICE', data=df1)
plt.show()

# %%
sns.scatterplot(x='QS_OVERALL' , y='SALES_PRICE', data=df1)
plt.show()

# %% [markdown]
# No relation btw QS_ROOM , QS_BEDROOM , QS_BATHROOM & QS_OVERALL features , will drop them

# %%
df1['Age'] = pd.DatetimeIndex(df1['DATE_SALE']).year - pd.DatetimeIndex(df1['DATE_BUILD']).year

# %%
df1.head()
# Out:
#    AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0     1      1004 2011-05-04            131          1           1       3
# 1     6      1986 2006-12-19             26          2           1       5
# 2     2       909 2012-02-04             70          1           1       3
# 3     4      1855 2010-03-13             14          3           2       5
# 4     1      1226 2009-10-05             84          1           1       3
#
#   SALE_COND  PARK_FACIL DATE_BUILD  ...  MZZONE  QS_ROOMS  QS_BATHROOM  \
# 0  AbNormal           1 1967-05-15  ...       1       4.0          3.9
# 1  AbNormal           0 1995-12-22  ...       5       4.9          4.2
# 2  AbNormal           1 1992-02-09  ...       6       4.1          3.8
# 3    Family           0 1988-03-18  ...       3       4.7          3.9
# 4  AbNormal           1 1979-10-13  ...       2       3.0          2.5
#
#    QS_BEDROOM  QS_OVERALL  SALES_PRICE  BUILDTYPE_Commercial  BUILDTYPE_House  \
# ...

# %%
df1.drop(['DATE_SALE','DIST_MAINROAD','SALE_COND','DATE_BUILD','QS_ROOMS','QS_BEDROOM','QS_BATHROOM','QS_OVERALL','SALES_PRICE'],axis=1,inplace=True)
df1.head()
# Out:
#    AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  UTILITY_AVAIL  \
# 0     1      1004          1           1       3           1              3
# 1     6      1986          2           1       5           0              3
# 2     2       909          1           1       3           1              1
# 3     4      1855          3           2       5           0              2
# 4     1      1226          1           1       3           1              3
#
#    STREET  MZZONE  BUILDTYPE_Commercial  BUILDTYPE_House  BUILDTYPE_Other  Age
# 0       2       1                     1                0                0   44
# 1       3       5                     1                0                0   11
# 2       3       6                     1                0                0   20
# 3       2       3                     0                0                1   22
# 4       3       2                     0                0                1   30

# %%
X = df1.values
Y = df['SALES_PRICE'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# Linear Regression

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train,y_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
print('R2 Score is : ' , r2_score(y_test,y_pred))
# Out:
# R2 Score is :  0.9148533344853078

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=200)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
print('R2 Score is : ' , r2_score(y_test,y_pred))
# Out:
# R2 Score is :  0.9889890262031898

# %% [markdown]
# Random Forest is giving us better results with R2 score of 0.989
